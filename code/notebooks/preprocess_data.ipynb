# %%
# !pip install transformers nltk wordcloud matplotlib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
utils_path = "/content/drive/MyDrive/MSc Data Science/DeepLearning_Applications/Incos_AI/utils"

# %%
import sys
sys.path.append(utils_path)

# %%
json_directory = "/content/drive/MyDrive/MSc Data Science/DeepLearning_Applications/Incos_AI/data"
output_file = "/content/drive/MyDrive/MSc Data Science/DeepLearning_Applications/Incos_AI/processed_chunks.json"

# %%
import nltk
nltk.download('punkt_tab')

from knowledge_base import DataProcessor

processor = DataProcessor(json_directory, output_file)
processed_chunks = processor.process_and_save()

print(f"Total chunks processed: {len(processed_chunks)}")
print("Sample chunks:")
for chunk in processed_chunks[:5]:
    print(f"Source: {chunk['source']}")
    print(f"Chunk: {chunk['text'][:100]}...")
# Out:
# Processed 63 chunks and saved to /content/drive/MyDrive/MSc Data Science/DeepLearning_Applications/Incos_AI/processed_chunks.json
# Total chunks processed: 63
# Sample chunks:
# Source: Academic_Integrity_Guidelines.json
# Chunk: academic integrity guidelines maintaining academic integrity fundamental requirement coursework stud...
# Source: Academic_Integrity_Guidelines.json
# Chunk: prohibited ensure uses clearly documented code integrity code submitted must written using thirdpart...
# Source: Coursework_Overview.json
# Chunk: deep learning coursework specification 2025 deep learning coursework involves developing comprehensi...
# Source: Coursework_Overview.json
# Chunk: sections introduction literature review methodology experiments results discussion conclusion report...
# Source: Coursework_Overview.json
# Chunk: solve realworld problem develop critical thinking problemsolving skills handson experimentation docu...
# ...
