# %%
from google.colab import drive
import json
from sentence_transformers import SentenceTransformer
import numpy as np

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append('/content/drive/MyDrive/MSc Data Science/DeepLearning_Applications/Incos_AI/utils')  # Adjust this path based on your folder structure

# %%
from embeddings import CorpusEmbedder

# Define paths
json_file_path = '/content/drive/MyDrive/MSc Data Science/DeepLearning_Applications/Incos_AI/processed_chunks.json'
output_file_path = '/content/drive/MyDrive/MSc Data Science/DeepLearning_Applications/Incos_AI/corpus_embeddings.json'

# Create an instance of CorpusEmbedder and process the data
embedder = CorpusEmbedder()
embedder.process(json_file_path, output_file_path)
# Out:
# Loading chunks...
# Generating embeddings...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Saving embeddings and metadata...
# Embeddings and metadata saved to /content/drive/MyDrive/MSc Data Science/DeepLearning_Applications/Incos_AI/corpus_embeddings.json
